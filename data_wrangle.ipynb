# %% [markdown]
# #Data Wrangling:
#
# Project: make machine learning model that will predict where the highest paid jobs are and what their titles are
#
# Input: where I am aiming to work, which in San Francisco Bay Area, California
# Output: Salary expectations and their respective titles
#
# Using a kaggle dataset: https://www.kaggle.com/datasets/ritiksharma07/data-science-job-listings-from-glassdoor
#
# And these bls reports: https://data.bls.gov/oes/#/occInd/One%20occupation%20for%20multiple%20industries
#
# 1.)First go over the kaggle dataset about data scientis postings in 2024
#
# 2.) Then go over the bls report on data scientist market in 2023

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Data-Science-Job_Listing.csv')

# %%
df.head(10)
# Out:
#    Position                                          Job Title  \
# 0         1                    Associate Stop Loss Underwriter
# 1         2                            Manager of Data Science
# 2         3                        Senior Data Product Manager
# 3         4                           Oncology Nurse Navigator
# 4         5  Head of Artificial Intelligence – Americas Region
# 5         6                                         IT Manager
# 6         7  Data Center Services Technician - IT, Crypto M...
# 7         8               Data Center Construction Coordinator
# 8         9                              Senior AIOps Engineer
# 9        10        Software Measurement and Estimation Analyst
#
#                                         Company Name        Location  \
# 0                          The Insurance Center\n2.7    Onalaska, WI
# 1                                Nuvative, Inc.\n3.4     Wichita, KS
# 2                                 ProviderTrust\n4.2   Nashville, TN
# 3                                 Inizio Engage\n3.6    Portland, OR
# 4                                      Covestro\n3.6  Pittsburgh, PA
# 5                            Western Welding Academy    Gillette, WY
# 6                                     Growler Mining  Tuscaloosa, AL
# 7                                    Applied Digital   Ellendale, ND
# 8               Health Data Analytics Institute\n4.4      Dedham, MA
# 9  Carnegie Mellon University Software Engineerin...  Pittsburgh, PA
#
#                                      Salary  Date  \
# 0              $57K - $84K (Glassdoor est.)  30d+
# 1            $106K - $157K (Glassdoor est.)  30d+
# 2            $105K - $141K (Glassdoor est.)   11d
# 3              $90K - $113K (Employer est.)    1d
# 4             $89K - $148K (Glassdoor est.)  30d+
# 5                      $90K (Employer est.)   26d
# 6  $22.00 - $28.00 Per Hour (Employer est.)  30d+
# 7               $58K - $80K (Employer est.)   23d
# 8             $151K - $175K (Employer est.)  30d+
# 9                                       NaN   11d
#
#                                                 Logo  \
# 0  https://media.glassdoor.com/sql/453835/the-ins...
# 1  https://media.glassdoor.com/sql/1384674/net-pa...
# 2  https://media.glassdoor.com/sql/1953857/hibob-...
# 3  https://media.glassdoor.com/sql/8794153/inizio...
# 4  https://media.glassdoor.com/sql/27128/covestro...
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8  https://media.glassdoor.com/sql/3037378/health...
# 9                                                NaN
#
#                                             Job Link  Company Rating
# 0  https://www.glassdoor.com/partner/jobListing.h...             2.7
# 1  https://www.glassdoor.com/partner/jobListing.h...             3.4
# 2  https://www.glassdoor.com/partner/jobListing.h...             4.2
# 3  https://www.glassdoor.com/partner/jobListing.h...             3.6
# 4  https://www.glassdoor.com/partner/jobListing.h...             3.6
# 5  https://www.glassdoor.com/partner/jobListing.h...             NaN
# 6  https://www.glassdoor.com/partner/jobListing.h...             NaN
# 7  https://www.glassdoor.com/partner/jobListing.h...             NaN
# 8  https://www.glassdoor.com/partner/jobListing.h...             4.4
# 9  https://www.glassdoor.com/partner/jobListing.h...             NaN

# %%
df.shape
# Out:
# (500, 9)

# %%
df.dtypes
# Out:
# Position            int64
# Job Title          object
# Company Name       object
# Location           object
# Salary             object
# Date               object
# Logo               object
# Job Link           object
# Company Rating    float64
# dtype: object

# %%
df.isna().sum()
# Out:
# Position           0
# Job Title          0
# Company Name       0
# Location           0
# Salary            62
# Date               0
# Logo              64
# Job Link           0
# Company Rating    61
# dtype: int64

# %%
df['Salary'].unique()
# Out:
# array(['$57K - $84K\xa0(Glassdoor est.)',
#        '$106K - $157K\xa0(Glassdoor est.)',
#        '$105K - $141K\xa0(Glassdoor est.)',
#        '$90K - $113K\xa0(Employer est.)',
#        '$89K - $148K\xa0(Glassdoor est.)', '$90K\xa0(Employer est.)',
#        '$22.00 - $28.00\xa0Per Hour\xa0(Employer est.)',
#        '$58K - $80K\xa0(Employer est.)',
#        '$151K - $175K\xa0(Employer est.)', nan,
#        '$166K - $245K\xa0(Employer est.)',
#        '$60K - $65K\xa0(Employer est.)',
#        '$112K - $169K\xa0(Glassdoor est.)',
#        '$140K - $170K\xa0(Employer est.)',
#        '$50.00\xa0Per Hour\xa0(Employer est.)',
#        '$153K - $200K\xa0(Employer est.)',
#        '$100K - $110K\xa0(Employer est.)',
#        '$120K - $150K\xa0(Employer est.)',
#        '$21.00 - $23.00\xa0Per Hour\xa0(Employer est.)',
#        '$37K - $55K\xa0(Glassdoor est.)',
#        '$111K - $166K\xa0(Employer est.)',
#        '$165K - $175K\xa0(Employer est.)',
#        '$40K - $46K\xa0(Employer est.)',
#        '$125K - $175K\xa0(Employer est.)',
#        '$105K - $130K\xa0(Employer est.)',
#        '$70.00 - $75.00\xa0Per Hour\xa0(Employer est.)',
#        '$100K - $105K\xa0(Employer est.)',
#        '$95K - $135K\xa0(Employer est.)',
#        '$75K - $108K\xa0(Glassdoor est.)',
#        '$214K - $310K\xa0(Employer est.)',
#        '$70.00 - $80.00\xa0Per Hour\xa0(Employer est.)',
#        '$45.00\xa0Per Hour\xa0(Employer est.)',
#        '$119K - $196K\xa0(Employer est.)',
#        '$165K - $248K\xa0(Employer est.)',
#        '$54K - $87K\xa0(Glassdoor est.)',
#        '$55K - $84K\xa0(Glassdoor est.)',
#        '$65K - $75K\xa0(Employer est.)',
#        '$98K - $174K\xa0(Employer est.)',
#        '$140K - $200K\xa0(Employer est.)',
#        '$52K - $82K\xa0(Glassdoor est.)',
#        '$75K - $125K\xa0(Employer est.)', '$85K\xa0(Employer est.)',
#        '$61K - $111K\xa0(Glassdoor est.)',
#        '$112K - $200K\xa0(Employer est.)',
#        '$117K - $160K\xa0(Glassdoor est.)', '$91K\xa0(Employer est.)',
#        '$86K - $155K\xa0(Employer est.)',
#        '$73K - $78K\xa0(Employer est.)',
#        '$125K - $200K\xa0(Employer est.)',
#        '$132K - $190K\xa0(Glassdoor est.)', '$95K\xa0(Employer est.)',
#        '$175K - $200K\xa0(Employer est.)', '$250K\xa0(Employer est.)',
#        '$90K - $120K\xa0(Employer est.)',
#        '$88K - $153K\xa0(Glassdoor est.)',
#        '$120K - $130K\xa0(Employer est.)',
#        '$90K - $144K\xa0(Glassdoor est.)',
#        '$90K - $95K\xa0(Employer est.)',
#        '$98K - $134K\xa0(Glassdoor est.)',
#        '$75K - $95K\xa0(Employer est.)', '$75K - $90K\xa0(Employer est.)',
#        '$140K - $145K\xa0(Employer est.)',
#        '$57K - $95K\xa0(Glassdoor est.)',
#        '$40.00 - $45.00\xa0Per Hour\xa0(Employer est.)',
#        '$61.00 - $76.00\xa0Per Hour\xa0(Employer est.)',
#        '$17.00\xa0Per Hour\xa0(Employer est.)',
#        '$98K - $131K\xa0(Glassdoor est.)',
#        '$22.00 - $50.00\xa0Per Hour\xa0(Employer est.)',
#        '$125K - $150K\xa0(Employer est.)',
#        '$65K - $80K\xa0(Employer est.)',
#        '$129K - $165K\xa0(Glassdoor est.)',
#        '$180K - $339K\xa0(Employer est.)',
#        '$150K - $250K\xa0(Employer est.)',
#        '$126K - $186K\xa0(Glassdoor est.)',
#        '$58K - $82K\xa0(Employer est.)',
#        '$69K - $108K\xa0(Glassdoor est.)',
#        '$86K - $120K\xa0(Employer est.)',
#        '$112K - $132K\xa0(Employer est.)',
#        '$135K - $160K\xa0(Employer est.)',
#        '$118K - $178K\xa0(Employer est.)', '$94K\xa0(Employer est.)',
#        '$120K\xa0(Employer est.)', '$130K - $175K\xa0(Employer est.)',
#        '$14.00\xa0Per Hour\xa0(Employer est.)',
#        '$102K - $154K\xa0(Glassdoor est.)',
#        '$60K - $70K\xa0(Employer est.)',
#        '$127K - $177K\xa0(Employer est.)',
#        '$109K - $168K\xa0(Glassdoor est.)',
#        '$130K - $155K\xa0(Employer est.)',
#        '$55.00 - $60.00\xa0Per Hour\xa0(Employer est.)',
#        '$22.05 - $50.00\xa0Per Hour\xa0(Employer est.)',
#        '$92K - $130K\xa0(Glassdoor est.)',
#        '$85K - $137K\xa0(Glassdoor est.)',
#        '$23.00\xa0Per Hour\xa0(Employer est.)',
#        '$103K - $143K\xa0(Employer est.)',
#        '$97K - $145K\xa0(Employer est.)',
#        '$67K - $102K\xa0(Glassdoor est.)',
#        '$20.00\xa0Per Hour\xa0(Employer est.)',
#        '$117K - $165K\xa0(Employer est.)',
#        '$52.25 - $60.50\xa0Per Hour\xa0(Employer est.)',
#        '$146K - $234K\xa0(Employer est.)',
#        '$125K - $135K\xa0(Employer est.)',
#        '$95K - $155K\xa0(Employer est.)',
#        '$63K - $97K\xa0(Glassdoor est.)',
#        '$153K - $196K\xa0(Glassdoor est.)',
#        '$53K - $77K\xa0(Glassdoor est.)',
#        '$140K - $150K\xa0(Employer est.)',
#        '$129K - $219K\xa0(Employer est.)',
#        '$63K - $89K\xa0(Employer est.)',
#        '$150K - $190K\xa0(Employer est.)',
#        '$90K - $140K\xa0(Employer est.)',
#        '$88K - $149K\xa0(Glassdoor est.)',
#        '$164K - $209K\xa0(Glassdoor est.)',
#        '$75K - $107K\xa0(Employer est.)',
#        '$69K - $125K\xa0(Employer est.)',
#        '$51K - $80K\xa0(Glassdoor est.)',
#        '$71K - $106K\xa0(Glassdoor est.)',
#        '$106K - $122K\xa0(Employer est.)',
#        '$55K - $60K\xa0(Employer est.)',
#        '$220K - $283K\xa0(Employer est.)',
#        '$188K - $357K\xa0(Employer est.)',
#        '$151K - $198K\xa0(Glassdoor est.)',
#        '$70K - $85K\xa0(Employer est.)',
#        '$66K - $102K\xa0(Glassdoor est.)',
#        '$32.00 - $35.00\xa0Per Hour\xa0(Employer est.)',
#        '$180K - $240K\xa0(Employer est.)',
#        '$151K - $153K\xa0(Employer est.)',
#        '$116K - $191K\xa0(Glassdoor est.)',
#        '$86K - $117K\xa0(Glassdoor est.)',
#        '$160K - $190K\xa0(Employer est.)',
#        '$60K - $100K\xa0(Employer est.)',
#        '$113K - $125K\xa0(Employer est.)',
#        '$160K - $180K\xa0(Employer est.)',
#        '$87K - $157K\xa0(Employer est.)',
#        '$77K - $139K\xa0(Employer est.)',
#        '$89K - $125K\xa0(Employer est.)',
#        '$150K - $210K\xa0(Employer est.)',
#        '$80K - $110K\xa0(Employer est.)',
#        '$55K - $65K\xa0(Employer est.)',
#        '$118K - $191K\xa0(Glassdoor est.)',
#        '$145K - $182K\xa0(Glassdoor est.)',
#        '$86K - $150K\xa0(Employer est.)',
#        '$72K - $132K\xa0(Glassdoor est.)',
#        '$103K - $137K\xa0(Glassdoor est.)', '$65K\xa0(Employer est.)',
#        '$93K - $146K\xa0(Glassdoor est.)',
#        '$40.00 - $50.00\xa0Per Hour\xa0(Employer est.)',
#        '$88K - $121K\xa0(Glassdoor est.)',
#        '$90K - $165K\xa0(Employer est.)', '$175K\xa0(Employer est.)',
#        '$93K - $125K\xa0(Employer est.)',
#        '$55.00 - $75.00\xa0Per Hour\xa0(Employer est.)',
#        '$89K - $127K\xa0(Glassdoor est.)',
#        '$75.00\xa0Per Hour\xa0(Employer est.)',
#        '$200K - $240K\xa0(Employer est.)',
#        '$143K - $191K\xa0(Glassdoor est.)',
#        '$83K - $168K\xa0(Employer est.)',
#        '$59K - $84K\xa0(Glassdoor est.)',
#        '$115K - $199K\xa0(Glassdoor est.)',
#        '$147K - $270K\xa0(Employer est.)',
#        '$65K - $70K\xa0(Employer est.)',
#        '$60K - $137K\xa0(Employer est.)',
#        '$107K - $147K\xa0(Glassdoor est.)',
#        '$99K - $130K\xa0(Employer est.)',
#        '$110K - $160K\xa0(Employer est.)',
#        '$61K - $100K\xa0(Glassdoor est.)',
#        '$59K - $111K\xa0(Glassdoor est.)',
#        '$88K - $124K\xa0(Glassdoor est.)', '$140K\xa0(Employer est.)',
#        '$115K - $173K\xa0(Glassdoor est.)',
#        '$57K - $98K\xa0(Employer est.)', '$68K - $71K\xa0(Employer est.)',
#        '$106K - $160K\xa0(Glassdoor est.)',
#        '$103K - $172K\xa0(Employer est.)',
#        '$97K - $162K\xa0(Employer est.)',
#        '$61K - $125K\xa0(Employer est.)',
#        '$92K - $129K\xa0(Glassdoor est.)',
#        '$62K - $107K\xa0(Employer est.)',
#        '$58K - $87K\xa0(Glassdoor est.)',
#        '$107K - $260K\xa0(Employer est.)',
#        '$76K - $172K\xa0(Employer est.)',
#        '$212K - $318K\xa0(Employer est.)',
#        '$39K - $60K\xa0(Employer est.)',
#        '$75K - $130K\xa0(Employer est.)',
#        '$50K - $60K\xa0(Employer est.)',
#        '$109K - $185K\xa0(Employer est.)',
#        '$121K - $204K\xa0(Employer est.)',
#        '$70K - $119K\xa0(Employer est.)',
#        '$108K - $172K\xa0(Employer est.)',
#        '$149K - $177K\xa0(Employer est.)',
#        '$51K - $95K\xa0(Glassdoor est.)',
#        '$85K - $100K\xa0(Employer est.)',
#        '$52K - $78K\xa0(Glassdoor est.)',
#        '$140K - $210K\xa0(Employer est.)',
#        '$86K - $180K\xa0(Employer est.)',
#        '$57K - $80K\xa0(Glassdoor est.)',
#        '$31.43 - $39.59\xa0Per Hour\xa0(Employer est.)',
#        '$106K - $151K\xa0(Glassdoor est.)',
#        '$31.45 - $42.55\xa0Per Hour\xa0(Employer est.)',
#        '$74K - $100K\xa0(Employer est.)',
#        '$25.00 - $35.00\xa0Per Hour\xa0(Employer est.)',
#        '$100K - $139K\xa0(Glassdoor est.)',
#        '$118K - $157K\xa0(Glassdoor est.)',
#        '$97K - $234K\xa0(Employer est.)',
#        '$128K - $160K\xa0(Employer est.)',
#        '$122K - $159K\xa0(Employer est.)',
#        '$200K - $260K\xa0(Employer est.)',
#        '$55.00 - $65.00\xa0Per Hour\xa0(Employer est.)',
#        '$137K - $182K\xa0(Glassdoor est.)',
#        '$102K - $140K\xa0(Glassdoor est.)',
#        '$24.00 - $50.00\xa0Per Hour\xa0(Employer est.)',
#        '$162K - $297K\xa0(Employer est.)',
#        '$72.52 - $116.03\xa0Per Hour\xa0(Employer est.)',
#        '$74K - $99K\xa0(Employer est.)',
#        '$164K - $203K\xa0(Employer est.)',
#        '$35.00 - $37.00\xa0Per Hour\xa0(Employer est.)',
#        '$74K - $110K\xa0(Glassdoor est.)',
#        '$78K - $129K\xa0(Glassdoor est.)',
#        '$91K - $132K\xa0(Glassdoor est.)',
#        '$98K - $135K\xa0(Employer est.)',
#        '$60.00 - $70.00\xa0Per Hour\xa0(Employer est.)',
#        '$50.72 - $69.74\xa0Per Hour\xa0(Employer est.)',
#        '$90K - $110K\xa0(Employer est.)',
#        '$190K - $270K\xa0(Employer est.)',
#        '$110K - $215K\xa0(Employer est.)',
#        '$83K - $152K\xa0(Glassdoor est.)',
#        '$30.00 - $50.00\xa0Per Hour\xa0(Employer est.)',
#        '$51K - $78K\xa0(Glassdoor est.)',
#        '$75K - $120K\xa0(Glassdoor est.)',
#        '$45.00 - $65.00\xa0Per Hour\xa0(Employer est.)',
#        '$141K - $247K\xa0(Employer est.)',
#        '$74K - $108K\xa0(Glassdoor est.)',
#        '$136K - $184K\xa0(Employer est.)',
#        '$194K - $260K\xa0(Employer est.)', '$107K\xa0(Employer est.)',
#        '$63K - $81K\xa0(Employer est.)',
#        '$113K - $191K\xa0(Employer est.)',
#        '$116K - $175K\xa0(Glassdoor est.)',
#        '$53K - $98K\xa0(Glassdoor est.)',
#        '$98K - $176K\xa0(Glassdoor est.)',
#        '$180K - $230K\xa0(Employer est.)',
#        '$68K - $127K\xa0(Glassdoor est.)',
#        '$145K - $207K\xa0(Glassdoor est.)',
#        '$52.81 - $71.45\xa0Per Hour\xa0(Employer est.)',
#        '$109K - $209K\xa0(Employer est.)',
#        '$78K - $131K\xa0(Glassdoor est.)',
#        '$98K - $193K\xa0(Employer est.)',
#        '$70K - $113K\xa0(Glassdoor est.)',
#        '$83K - $124K\xa0(Employer est.)',
#        '$75K - $85K\xa0(Employer est.)', '$158K\xa0(Employer est.)',
#        '$150K - $200K\xa0(Employer est.)',
#        '$60K - $75K\xa0(Employer est.)',
#        '$103K - $153K\xa0(Glassdoor est.)',
#        '$94K - $119K\xa0(Glassdoor est.)', '$100K\xa0(Employer est.)',
#        '$62.00 - $72.00\xa0Per Hour\xa0(Employer est.)',
#        '$118K - $134K\xa0(Employer est.)',
#        '$98K - $142K\xa0(Employer est.)',
#        '$90K - $130K\xa0(Employer est.)',
#        '$67K - $94K\xa0(Glassdoor est.)',
#        '$76K - $186K\xa0(Employer est.)',
#        '$76K - $122K\xa0(Glassdoor est.)',
#        '$169K - $271K\xa0(Employer est.)',
#        '$135K - $150K\xa0(Employer est.)',
#        '$160K - $269K\xa0(Employer est.)',
#        '$44.12 - $70.00\xa0Per Hour\xa0(Employer est.)',
#        '$33.00 - $39.00\xa0Per Hour\xa0(Employer est.)'], dtype=object)

# %% [markdown]
# A couple of things to edit:
#
# 1.) get rid of the \n.. on the company names
#
# 2.) Split location between city and state
#
# 3.) split the salary into a lower and upper bounds
#
# 4.) Drop date, logo, job link

# %% [markdown]
# 1.) lets clean up the company name

# %%
def name_cleaner(df_col):
    cue = '\n'
    name_list = []
    for x in df_col:
        
        temp_container = []
        end = 0
        for y in range(len(x)):
            temp_container.append(x[y])
    
            if x[y] in cue and end == 0:
                end = y
        if cue not in temp_container:
            new_list = temp_container
        else:
            new_list = temp_container[:end]
        
        new_name = ''.join(new_list)
        name_list.append(new_name)
    #name_dict = {'company_name':name_list}
    return name_list

# %%
new_names = name_cleaner(df['Company Name'])

# %%
names_series=pd.Series(data=new_names)

# %%
names_series.shape
# Out:
# (500,)

# %%
df = pd.concat([df,names_series], axis=1)

# %%
df =df.rename(columns={0:'company_name'})

# %%
df = df.drop(columns='Company Name')

# %%
df.head()
# Out:
#    Position                                          Job Title  \
# 0         1                    Associate Stop Loss Underwriter
# 1         2                            Manager of Data Science
# 2         3                        Senior Data Product Manager
# 3         4                           Oncology Nurse Navigator
# 4         5  Head of Artificial Intelligence – Americas Region
#
#          Location                          Salary  Date  \
# 0    Onalaska, WI    $57K - $84K (Glassdoor est.)  30d+
# 1     Wichita, KS  $106K - $157K (Glassdoor est.)  30d+
# 2   Nashville, TN  $105K - $141K (Glassdoor est.)   11d
# 3    Portland, OR    $90K - $113K (Employer est.)    1d
# 4  Pittsburgh, PA   $89K - $148K (Glassdoor est.)  30d+
#
#                                                 Logo  \
# 0  https://media.glassdoor.com/sql/453835/the-ins...
# 1  https://media.glassdoor.com/sql/1384674/net-pa...
# 2  https://media.glassdoor.com/sql/1953857/hibob-...
# 3  https://media.glassdoor.com/sql/8794153/inizio...
# 4  https://media.glassdoor.com/sql/27128/covestro...
#
#                                             Job Link  Company Rating  \
# 0  https://www.glassdoor.com/partner/jobListing.h...             2.7
# 1  https://www.glassdoor.com/partner/jobListing.h...             3.4
# 2  https://www.glassdoor.com/partner/jobListing.h...             4.2
# 3  https://www.glassdoor.com/partner/jobListing.h...             3.6
# 4  https://www.glassdoor.com/partner/jobListing.h...             3.6
#
#            company_name
# 0  The Insurance Center
# 1        Nuvative, Inc.
# 2         ProviderTrust
# 3         Inizio Engage
# 4              Covestro

# %% [markdown]
# 2.) Split location into city and state columns

# %%
df['Location'].unique()
# Out:
# array(['Onalaska, WI', 'Wichita, KS', 'Nashville, TN', 'Portland, OR',
#        'Pittsburgh, PA', 'Gillette, WY', 'Tuscaloosa, AL',
#        'Ellendale, ND', 'Dedham, MA', 'Tampa, FL',
#        'Palm Beach Gardens, FL', 'Miami, FL', 'Rocky River, OH',
#        'San Diego, CA', 'Eau Claire, WI', 'Lexington, MA', 'Boston, MA',
#        'Phoenix, AZ', 'Dallas, TX', 'Austin, TX', 'Minneapolis, MN',
#        'Vernon Hills, IL', 'Coral Gables, FL', 'Mount Laurel, NJ',
#        'Springfield, VA', 'Chester, PA', 'Durham, NC', 'Charlotte, NC',
#        'Independence, OH', 'Atlanta, GA', 'Washington, DC', 'Denver, CO',
#        'West Chester, OH', 'Patuxent River, MD', 'Remote',
#        'United States', 'Hartford, CT', 'Memphis, TN', 'Los Angeles, CA',
#        'Las Vegas, NV', 'Tallahassee, FL', 'Anaheim, CA', 'Pensacola, FL',
#        'Fort Worth, TX', 'Reston, VA', 'Huntsville, AL',
#        'Offutt A F B, NE', 'Emeryville, CA', 'Basking Ridge, NJ',
#        'Myrtle Point, OR', 'Bolingbrook, IL', 'Scott Air Force Base, IL',
#        'West Palm Beach, FL', 'Newark, DE', 'Buffalo, NY',
#        'Chantilly, VA', 'Woodcliff Lake, NJ', 'Seattle, WA', 'Plano, TX',
#        'Tustin, CA', 'Battle Creek, MI', 'Santa Clara, CA',
#        'Bridgewater, NJ', 'Lexington, KY', 'Rancho Cucamonga, CA',
#        'Riverwoods, IL', 'Franklin, TN', 'Madison, WI', 'McLean, VA',
#        'Houston, TX', 'Chicago, IL', 'Nashua, NH', 'Campbell, CA',
#        'Arlington, VA', 'Rensselaer, NY', 'Selma, AL', 'New York, NY',
#        'Irving, TX', 'Alpharetta, GA', 'Trenton, NJ', 'Carlsbad, CA',
#        'Stamford, CT', 'Groton, CT', 'Paramus, NJ', 'Charlottesville, VA',
#        'West Lafayette, IN', 'Jersey City, NJ', 'Dayton, OH',
#        'Rego Park, NY', 'Texas', 'Kennewick, WA', 'Palo Alto, CA',
#        'Princeton, NJ', 'Juno Beach, FL', 'Pleasanton, CA', 'New Jersey',
#        'Syracuse, NY', 'Malvern, PA', 'Deerfield, IL', 'Spring, TX',
#        'Fort Lauderdale, FL', 'Santa Monica, CA', 'Bellevue, WA',
#        'Spring House, PA', 'Redmond, WA', 'Wausau, WI', 'Georgetown, TX',
#        'Irvine, CA', 'Columbus, OH', 'Linthicum, MD', 'Greenville, NC',
#        'Jeffersonville, IN', 'Bethesda, MD', 'Westwood, MA', 'Newark, NJ',
#        'New Berlin, WI', 'Arlington, TX', 'Richmond, VA', 'Columbia, MD',
#        'Chandler, AZ', 'Cincinnati, OH', 'Miami Lakes, FL',
#        'Farmington, CT', 'Plainsboro, NJ', 'San Antonio, TX',
#        'Boca Raton, FL', 'Manassas, VA', 'Cambridge, MA', 'Lake Mary, FL',
#        'Albany, GA', 'Fort Walton Beach, FL', 'Wilmington, DE',
#        'Detroit, MI', 'San Jose, CA', 'San Ramon, CA', 'Sacramento, CA',
#        'Cleveland, OH', 'Greenville, SC', 'Philadelphia, PA',
#        'Tysons Corner, VA', 'Ashburn, VA', 'Ann Arbor, MI', 'Radnor, PA',
#        'Concord, NH', 'Rockville, MD', 'Sandy, UT', 'Glendale, CA',
#        'North Carolina', 'Los Gatos, CA', 'Centennial, CO', 'Fairfax, VA',
#        'Thousand Oaks, CA', 'Greenville, MS', 'Shelton, WA',
#        'Marlborough, MA', 'Lakeview, Nassau, NY', 'Miramar, FL',
#        'Milwaukee, WI', 'Fremont, CA', 'Lancaster, PA', 'Lafayette, LA',
#        'Research Triangle Park, NC'], dtype=object)

# %%
def city_state_split(df_col):
    triggers = ['Remote', 'United States']
    city_list = []
    state_list = []
    for x in df_col:
        container= []
        if x in triggers:
            city_list.append(x)
            state_list.append(x)
        else:
            for y in range(len(x)):
                container.append(x[y])
                if x[y] == ',':
                    ind = y
            city = container[:ind]
            city = ''.join(city)
            city_list.append(city)
            state = container[(ind+2):]
            state = ''.join(state)
            state_list.append(state)
        
    return city_list, state_list

# %%
split = city_state_split(df['Location'])

# %%
city_series = pd.Series(data=split[0])

# %%
state_series = pd.Series(data=split[1])

# %%
df = pd.concat([city_series, df], axis=1)

# %%
df =df.rename(columns={0:'city'})

# %%
df = pd.concat([state_series, df], axis=1)

# %%
df = df.rename(columns={0:'state'})

# %%
df = df.drop(columns='Location')

# %%
df.head(10)
# Out:
#   state        city  Position  \
# 0    WI    Onalaska         1
# 1    KS     Wichita         2
# 2    TN   Nashville         3
# 3    OR    Portland         4
# 4    PA  Pittsburgh         5
# 5    WY    Gillette         6
# 6    AL  Tuscaloosa         7
# 7    ND   Ellendale         8
# 8    MA      Dedham         9
# 9    PA  Pittsburgh        10
#
#                                            Job Title  \
# 0                    Associate Stop Loss Underwriter
# 1                            Manager of Data Science
# 2                        Senior Data Product Manager
# 3                           Oncology Nurse Navigator
# 4  Head of Artificial Intelligence – Americas Region
# 5                                         IT Manager
# 6  Data Center Services Technician - IT, Crypto M...
# 7               Data Center Construction Coordinator
# 8                              Senior AIOps Engineer
# 9        Software Measurement and Estimation Analyst
#
#                                      Salary  Date  \
# 0              $57K - $84K (Glassdoor est.)  30d+
# 1            $106K - $157K (Glassdoor est.)  30d+
# 2            $105K - $141K (Glassdoor est.)   11d
# 3              $90K - $113K (Employer est.)    1d
# 4             $89K - $148K (Glassdoor est.)  30d+
# 5                      $90K (Employer est.)   26d
# 6  $22.00 - $28.00 Per Hour (Employer est.)  30d+
# 7               $58K - $80K (Employer est.)   23d
# 8             $151K - $175K (Employer est.)  30d+
# 9                                       NaN   11d
#
#                                                 Logo  \
# 0  https://media.glassdoor.com/sql/453835/the-ins...
# 1  https://media.glassdoor.com/sql/1384674/net-pa...
# 2  https://media.glassdoor.com/sql/1953857/hibob-...
# 3  https://media.glassdoor.com/sql/8794153/inizio...
# 4  https://media.glassdoor.com/sql/27128/covestro...
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8  https://media.glassdoor.com/sql/3037378/health...
# 9                                                NaN
#
#                                             Job Link  Company Rating  \
# 0  https://www.glassdoor.com/partner/jobListing.h...             2.7
# 1  https://www.glassdoor.com/partner/jobListing.h...             3.4
# 2  https://www.glassdoor.com/partner/jobListing.h...             4.2
# 3  https://www.glassdoor.com/partner/jobListing.h...             3.6
# 4  https://www.glassdoor.com/partner/jobListing.h...             3.6
# 5  https://www.glassdoor.com/partner/jobListing.h...             NaN
# 6  https://www.glassdoor.com/partner/jobListing.h...             NaN
# 7  https://www.glassdoor.com/partner/jobListing.h...             NaN
# 8  https://www.glassdoor.com/partner/jobListing.h...             4.4
# 9  https://www.glassdoor.com/partner/jobListing.h...             NaN
#
#                                         company_name
# 0                               The Insurance Center
# 1                                     Nuvative, Inc.
# 2                                      ProviderTrust
# 3                                      Inizio Engage
# 4                                           Covestro
# 5                            Western Welding Academy
# 6                                     Growler Mining
# 7                                    Applied Digital
# 8                    Health Data Analytics Institute
# 9  Carnegie Mellon University Software Engineerin...

# %%
df.loc[df['state'] == 'olina','city'] = 'Not Listed'
df.loc[df['state'] == 'olina','state'] = 'NC'

# %%
for x in range(len(df['state'])):
    if df.loc[x,'state'] == '':
        print (x)
# Out:
# 159

# %%
df.iloc[159]
# Out:
# state
# city                                                          Texas
# Position                                                        160
# Job Title                                            Data Scientist
# Salary                     $55.00 - $60.00 Per Hour (Employer est.)
# Date                                                             2d
# Logo                                                            NaN
# Job Link          https://www.glassdoor.com/partner/jobListing.h...
# Company Rating                                                  3.0
# company_name                                          Technocore360
# Name: 159, dtype: object

# %%
df.loc[df['state'] == '','city'] = 'Not Listed'
df.loc[df['state'] == '','state'] = 'TX'

# %%
for x in range(len(df['state'])):
    if df.loc[x,'state'] == 'y':
        print (x)
# Out:
# 169

# %%
df.iloc[169]
# Out:
# state                                                             y
# city                                                        New Jer
# Position                                                        170
# Job Title                               Data Science - Optimization
# Salary                                                          NaN
# Date                                                             3d
# Logo              https://media.glassdoor.com/sql/717029/tiger-a...
# Job Link          https://www.glassdoor.com/partner/jobListing.h...
# Company Rating                                                  3.9
# company_name                                        Tiger Analytics
# Name: 169, dtype: object

# %%
df.loc[df['state'] == 'y','city'] = 'Not Listed'
df.loc[df['state'] == 'y','state'] = 'NJ'

# %%
df['state'].unique()
# Out:
# array(['WI', 'KS', 'TN', 'OR', 'PA', 'WY', 'AL', 'ND', 'MA', 'FL', 'OH',
#        'CA', 'AZ', 'TX', 'MN', 'IL', 'NJ', 'VA', 'NC', 'GA', 'DC', 'CO',
#        'MD', 'Remote', 'United States', 'CT', 'NV', 'NE', 'DE', 'NY',
#        'WA', 'MI', 'KY', 'NH', 'IN', 'SC', 'UT', 'MS', 'LA'], dtype=object)

# %% [markdown]
# Maybe should consider adding a column to indicate whether remote or not in a one hot encoding fashion

# %% [markdown]
# 3.) Time to edit the salary column

# %%
df['Salary'] = df['Salary'].fillna(0)

# %%
df['Salary'].unique()
# Out:
# array(['$57K - $84K\xa0(Glassdoor est.)',
#        '$106K - $157K\xa0(Glassdoor est.)',
#        '$105K - $141K\xa0(Glassdoor est.)',
#        '$90K - $113K\xa0(Employer est.)',
#        '$89K - $148K\xa0(Glassdoor est.)', '$90K\xa0(Employer est.)',
#        '$22.00 - $28.00\xa0Per Hour\xa0(Employer est.)',
#        '$58K - $80K\xa0(Employer est.)',
#        '$151K - $175K\xa0(Employer est.)', 0,
#        '$166K - $245K\xa0(Employer est.)',
#        '$60K - $65K\xa0(Employer est.)',
#        '$112K - $169K\xa0(Glassdoor est.)',
#        '$140K - $170K\xa0(Employer est.)',
#        '$50.00\xa0Per Hour\xa0(Employer est.)',
#        '$153K - $200K\xa0(Employer est.)',
#        '$100K - $110K\xa0(Employer est.)',
#        '$120K - $150K\xa0(Employer est.)',
#        '$21.00 - $23.00\xa0Per Hour\xa0(Employer est.)',
#        '$37K - $55K\xa0(Glassdoor est.)',
#        '$111K - $166K\xa0(Employer est.)',
#        '$165K - $175K\xa0(Employer est.)',
#        '$40K - $46K\xa0(Employer est.)',
#        '$125K - $175K\xa0(Employer est.)',
#        '$105K - $130K\xa0(Employer est.)',
#        '$70.00 - $75.00\xa0Per Hour\xa0(Employer est.)',
#        '$100K - $105K\xa0(Employer est.)',
#        '$95K - $135K\xa0(Employer est.)',
#        '$75K - $108K\xa0(Glassdoor est.)',
#        '$214K - $310K\xa0(Employer est.)',
#        '$70.00 - $80.00\xa0Per Hour\xa0(Employer est.)',
#        '$45.00\xa0Per Hour\xa0(Employer est.)',
#        '$119K - $196K\xa0(Employer est.)',
#        '$165K - $248K\xa0(Employer est.)',
#        '$54K - $87K\xa0(Glassdoor est.)',
#        '$55K - $84K\xa0(Glassdoor est.)',
#        '$65K - $75K\xa0(Employer est.)',
#        '$98K - $174K\xa0(Employer est.)',
#        '$140K - $200K\xa0(Employer est.)',
#        '$52K - $82K\xa0(Glassdoor est.)',
#        '$75K - $125K\xa0(Employer est.)', '$85K\xa0(Employer est.)',
#        '$61K - $111K\xa0(Glassdoor est.)',
#        '$112K - $200K\xa0(Employer est.)',
#        '$117K - $160K\xa0(Glassdoor est.)', '$91K\xa0(Employer est.)',
#        '$86K - $155K\xa0(Employer est.)',
#        '$73K - $78K\xa0(Employer est.)',
#        '$125K - $200K\xa0(Employer est.)',
#        '$132K - $190K\xa0(Glassdoor est.)', '$95K\xa0(Employer est.)',
#        '$175K - $200K\xa0(Employer est.)', '$250K\xa0(Employer est.)',
#        '$90K - $120K\xa0(Employer est.)',
#        '$88K - $153K\xa0(Glassdoor est.)',
#        '$120K - $130K\xa0(Employer est.)',
#        '$90K - $144K\xa0(Glassdoor est.)',
#        '$90K - $95K\xa0(Employer est.)',
#        '$98K - $134K\xa0(Glassdoor est.)',
#        '$75K - $95K\xa0(Employer est.)', '$75K - $90K\xa0(Employer est.)',
#        '$140K - $145K\xa0(Employer est.)',
#        '$57K - $95K\xa0(Glassdoor est.)',
#        '$40.00 - $45.00\xa0Per Hour\xa0(Employer est.)',
#        '$61.00 - $76.00\xa0Per Hour\xa0(Employer est.)',
#        '$17.00\xa0Per Hour\xa0(Employer est.)',
#        '$98K - $131K\xa0(Glassdoor est.)',
#        '$22.00 - $50.00\xa0Per Hour\xa0(Employer est.)',
#        '$125K - $150K\xa0(Employer est.)',
#        '$65K - $80K\xa0(Employer est.)',
#        '$129K - $165K\xa0(Glassdoor est.)',
#        '$180K - $339K\xa0(Employer est.)',
#        '$150K - $250K\xa0(Employer est.)',
#        '$126K - $186K\xa0(Glassdoor est.)',
#        '$58K - $82K\xa0(Employer est.)',
#        '$69K - $108K\xa0(Glassdoor est.)',
#        '$86K - $120K\xa0(Employer est.)',
#        '$112K - $132K\xa0(Employer est.)',
#        '$135K - $160K\xa0(Employer est.)',
#        '$118K - $178K\xa0(Employer est.)', '$94K\xa0(Employer est.)',
#        '$120K\xa0(Employer est.)', '$130K - $175K\xa0(Employer est.)',
#        '$14.00\xa0Per Hour\xa0(Employer est.)',
#        '$102K - $154K\xa0(Glassdoor est.)',
#        '$60K - $70K\xa0(Employer est.)',
#        '$127K - $177K\xa0(Employer est.)',
#        '$109K - $168K\xa0(Glassdoor est.)',
#        '$130K - $155K\xa0(Employer est.)',
#        '$55.00 - $60.00\xa0Per Hour\xa0(Employer est.)',
#        '$22.05 - $50.00\xa0Per Hour\xa0(Employer est.)',
#        '$92K - $130K\xa0(Glassdoor est.)',
#        '$85K - $137K\xa0(Glassdoor est.)',
#        '$23.00\xa0Per Hour\xa0(Employer est.)',
#        '$103K - $143K\xa0(Employer est.)',
#        '$97K - $145K\xa0(Employer est.)',
#        '$67K - $102K\xa0(Glassdoor est.)',
#        '$20.00\xa0Per Hour\xa0(Employer est.)',
#        '$117K - $165K\xa0(Employer est.)',
#        '$52.25 - $60.50\xa0Per Hour\xa0(Employer est.)',
#        '$146K - $234K\xa0(Employer est.)',
#        '$125K - $135K\xa0(Employer est.)',
#        '$95K - $155K\xa0(Employer est.)',
#        '$63K - $97K\xa0(Glassdoor est.)',
#        '$153K - $196K\xa0(Glassdoor est.)',
#        '$53K - $77K\xa0(Glassdoor est.)',
#        '$140K - $150K\xa0(Employer est.)',
#        '$129K - $219K\xa0(Employer est.)',
#        '$63K - $89K\xa0(Employer est.)',
#        '$150K - $190K\xa0(Employer est.)',
#        '$90K - $140K\xa0(Employer est.)',
#        '$88K - $149K\xa0(Glassdoor est.)',
#        '$164K - $209K\xa0(Glassdoor est.)',
#        '$75K - $107K\xa0(Employer est.)',
#        '$69K - $125K\xa0(Employer est.)',
#        '$51K - $80K\xa0(Glassdoor est.)',
#        '$71K - $106K\xa0(Glassdoor est.)',
#        '$106K - $122K\xa0(Employer est.)',
#        '$55K - $60K\xa0(Employer est.)',
#        '$220K - $283K\xa0(Employer est.)',
#        '$188K - $357K\xa0(Employer est.)',
#        '$151K - $198K\xa0(Glassdoor est.)',
#        '$70K - $85K\xa0(Employer est.)',
#        '$66K - $102K\xa0(Glassdoor est.)',
#        '$32.00 - $35.00\xa0Per Hour\xa0(Employer est.)',
#        '$180K - $240K\xa0(Employer est.)',
#        '$151K - $153K\xa0(Employer est.)',
#        '$116K - $191K\xa0(Glassdoor est.)',
#        '$86K - $117K\xa0(Glassdoor est.)',
#        '$160K - $190K\xa0(Employer est.)',
#        '$60K - $100K\xa0(Employer est.)',
#        '$113K - $125K\xa0(Employer est.)',
#        '$160K - $180K\xa0(Employer est.)',
#        '$87K - $157K\xa0(Employer est.)',
#        '$77K - $139K\xa0(Employer est.)',
#        '$89K - $125K\xa0(Employer est.)',
#        '$150K - $210K\xa0(Employer est.)',
#        '$80K - $110K\xa0(Employer est.)',
#        '$55K - $65K\xa0(Employer est.)',
#        '$118K - $191K\xa0(Glassdoor est.)',
#        '$145K - $182K\xa0(Glassdoor est.)',
#        '$86K - $150K\xa0(Employer est.)',
#        '$72K - $132K\xa0(Glassdoor est.)',
#        '$103K - $137K\xa0(Glassdoor est.)', '$65K\xa0(Employer est.)',
#        '$93K - $146K\xa0(Glassdoor est.)',
#        '$40.00 - $50.00\xa0Per Hour\xa0(Employer est.)',
#        '$88K - $121K\xa0(Glassdoor est.)',
#        '$90K - $165K\xa0(Employer est.)', '$175K\xa0(Employer est.)',
#        '$93K - $125K\xa0(Employer est.)',
#        '$55.00 - $75.00\xa0Per Hour\xa0(Employer est.)',
#        '$89K - $127K\xa0(Glassdoor est.)',
#        '$75.00\xa0Per Hour\xa0(Employer est.)',
#        '$200K - $240K\xa0(Employer est.)',
#        '$143K - $191K\xa0(Glassdoor est.)',
#        '$83K - $168K\xa0(Employer est.)',
#        '$59K - $84K\xa0(Glassdoor est.)',
#        '$115K - $199K\xa0(Glassdoor est.)',
#        '$147K - $270K\xa0(Employer est.)',
#        '$65K - $70K\xa0(Employer est.)',
#        '$60K - $137K\xa0(Employer est.)',
#        '$107K - $147K\xa0(Glassdoor est.)',
#        '$99K - $130K\xa0(Employer est.)',
#        '$110K - $160K\xa0(Employer est.)',
#        '$61K - $100K\xa0(Glassdoor est.)',
#        '$59K - $111K\xa0(Glassdoor est.)',
#        '$88K - $124K\xa0(Glassdoor est.)', '$140K\xa0(Employer est.)',
#        '$115K - $173K\xa0(Glassdoor est.)',
#        '$57K - $98K\xa0(Employer est.)', '$68K - $71K\xa0(Employer est.)',
#        '$106K - $160K\xa0(Glassdoor est.)',
#        '$103K - $172K\xa0(Employer est.)',
#        '$97K - $162K\xa0(Employer est.)',
#        '$61K - $125K\xa0(Employer est.)',
#        '$92K - $129K\xa0(Glassdoor est.)',
#        '$62K - $107K\xa0(Employer est.)',
#        '$58K - $87K\xa0(Glassdoor est.)',
#        '$107K - $260K\xa0(Employer est.)',
#        '$76K - $172K\xa0(Employer est.)',
#        '$212K - $318K\xa0(Employer est.)',
#        '$39K - $60K\xa0(Employer est.)',
#        '$75K - $130K\xa0(Employer est.)',
#        '$50K - $60K\xa0(Employer est.)',
#        '$109K - $185K\xa0(Employer est.)',
#        '$121K - $204K\xa0(Employer est.)',
#        '$70K - $119K\xa0(Employer est.)',
#        '$108K - $172K\xa0(Employer est.)',
#        '$149K - $177K\xa0(Employer est.)',
#        '$51K - $95K\xa0(Glassdoor est.)',
#        '$85K - $100K\xa0(Employer est.)',
#        '$52K - $78K\xa0(Glassdoor est.)',
#        '$140K - $210K\xa0(Employer est.)',
#        '$86K - $180K\xa0(Employer est.)',
#        '$57K - $80K\xa0(Glassdoor est.)',
#        '$31.43 - $39.59\xa0Per Hour\xa0(Employer est.)',
#        '$106K - $151K\xa0(Glassdoor est.)',
#        '$31.45 - $42.55\xa0Per Hour\xa0(Employer est.)',
#        '$74K - $100K\xa0(Employer est.)',
#        '$25.00 - $35.00\xa0Per Hour\xa0(Employer est.)',
#        '$100K - $139K\xa0(Glassdoor est.)',
#        '$118K - $157K\xa0(Glassdoor est.)',
#        '$97K - $234K\xa0(Employer est.)',
#        '$128K - $160K\xa0(Employer est.)',
#        '$122K - $159K\xa0(Employer est.)',
#        '$200K - $260K\xa0(Employer est.)',
#        '$55.00 - $65.00\xa0Per Hour\xa0(Employer est.)',
#        '$137K - $182K\xa0(Glassdoor est.)',
#        '$102K - $140K\xa0(Glassdoor est.)',
#        '$24.00 - $50.00\xa0Per Hour\xa0(Employer est.)',
#        '$162K - $297K\xa0(Employer est.)',
#        '$72.52 - $116.03\xa0Per Hour\xa0(Employer est.)',
#        '$74K - $99K\xa0(Employer est.)',
#        '$164K - $203K\xa0(Employer est.)',
#        '$35.00 - $37.00\xa0Per Hour\xa0(Employer est.)',
#        '$74K - $110K\xa0(Glassdoor est.)',
#        '$78K - $129K\xa0(Glassdoor est.)',
#        '$91K - $132K\xa0(Glassdoor est.)',
#        '$98K - $135K\xa0(Employer est.)',
#        '$60.00 - $70.00\xa0Per Hour\xa0(Employer est.)',
#        '$50.72 - $69.74\xa0Per Hour\xa0(Employer est.)',
#        '$90K - $110K\xa0(Employer est.)',
#        '$190K - $270K\xa0(Employer est.)',
#        '$110K - $215K\xa0(Employer est.)',
#        '$83K - $152K\xa0(Glassdoor est.)',
#        '$30.00 - $50.00\xa0Per Hour\xa0(Employer est.)',
#        '$51K - $78K\xa0(Glassdoor est.)',
#        '$75K - $120K\xa0(Glassdoor est.)',
#        '$45.00 - $65.00\xa0Per Hour\xa0(Employer est.)',
#        '$141K - $247K\xa0(Employer est.)',
#        '$74K - $108K\xa0(Glassdoor est.)',
#        '$136K - $184K\xa0(Employer est.)',
#        '$194K - $260K\xa0(Employer est.)', '$107K\xa0(Employer est.)',
#        '$63K - $81K\xa0(Employer est.)',
#        '$113K - $191K\xa0(Employer est.)',
#        '$116K - $175K\xa0(Glassdoor est.)',
#        '$53K - $98K\xa0(Glassdoor est.)',
#        '$98K - $176K\xa0(Glassdoor est.)',
#        '$180K - $230K\xa0(Employer est.)',
#        '$68K - $127K\xa0(Glassdoor est.)',
#        '$145K - $207K\xa0(Glassdoor est.)',
#        '$52.81 - $71.45\xa0Per Hour\xa0(Employer est.)',
#        '$109K - $209K\xa0(Employer est.)',
#        '$78K - $131K\xa0(Glassdoor est.)',
#        '$98K - $193K\xa0(Employer est.)',
#        '$70K - $113K\xa0(Glassdoor est.)',
#        '$83K - $124K\xa0(Employer est.)',
#        '$75K - $85K\xa0(Employer est.)', '$158K\xa0(Employer est.)',
#        '$150K - $200K\xa0(Employer est.)',
#        '$60K - $75K\xa0(Employer est.)',
#        '$103K - $153K\xa0(Glassdoor est.)',
#        '$94K - $119K\xa0(Glassdoor est.)', '$100K\xa0(Employer est.)',
#        '$62.00 - $72.00\xa0Per Hour\xa0(Employer est.)',
#        '$118K - $134K\xa0(Employer est.)',
#        '$98K - $142K\xa0(Employer est.)',
#        '$90K - $130K\xa0(Employer est.)',
#        '$67K - $94K\xa0(Glassdoor est.)',
#        '$76K - $186K\xa0(Employer est.)',
#        '$76K - $122K\xa0(Glassdoor est.)',
#        '$169K - $271K\xa0(Employer est.)',
#        '$135K - $150K\xa0(Employer est.)',
#        '$160K - $269K\xa0(Employer est.)',
#        '$44.12 - $70.00\xa0Per Hour\xa0(Employer est.)',
#        '$33.00 - $39.00\xa0Per Hour\xa0(Employer est.)'], dtype=object)

# %%
def salary_split(df_col):
    lower_list = []
    upper_list = []
    nan_val = float('nan') 
    for x in df_col:
        container= []
        if x == 0:
            lower_list.append(np.nan)
            upper_list.append(np.nan)
            
        
        else:
            
            k_count = 0
            p_count = 0
            d_count = 0
            
            k_ind = 0
            k2_ind = 0
            
            p_ind = 0
            p2_ind = 0
            
            d_ind = 0
            d2_ind = 0
            for y in range(len(x)):
                container.append(x[y])
                if x[y] == '$' and d_count == 0:
                    d_count += 1
                    d_ind = y
                elif x[y] == '$' and d_count == 1:
                    d_count += 1
                    d2_ind = y
                
                elif x[y] == 'K' and k_count == 0:
                    k_count += 1
                    k_ind = y
                elif x[y] == 'K' and k_count == 1:
                    k_count += 1
                    k2_ind = y 
                
                elif x[y] == '.' and p_count == 0:
                    p_count +=1
                    p_ind = y
                    
                elif x[y] == '.' and p_count == 1:
                    p_count +=1
                    p2_ind = y
                    
                elif x[y] == '.' and p_count == 2:
                    p_count +=1
                
            
            
            if k_count == 1:
                num = container[d_ind+1:k_ind]
                num = ''.join(num)
                num = num +'000'
                lower_list.append(num)
                upper_list.append(num)
                
            elif k_count == 2:
                low_num = container[d_ind+1:k_ind]
                low_num = ''.join(low_num)
                low_num = low_num +'000'
                lower_list.append(low_num)
            
                high_num = container[d2_ind+1:k2_ind]
                high_num = ''.join(high_num)
                high_num = high_num +'000'
                upper_list.append(high_num)
            
            
            elif p_count == 3:
                low_num = container[d_ind+1:p_ind]
                low_num = ''.join(low_num)
                low_num = int(low_num)
                low_num = low_num * 2080
                low_num = str(low_num)
                lower_list.append(low_num)
                
                high_num = container[d2_ind+1:p2_ind]
                high_num = ''.join(high_num)
                high_num = int(high_num)
                high_num = high_num * 2080
                high_num = str(high_num)
                upper_list.append(high_num)
            
            elif p_count == 2:
                num = container[d_ind+1:p_ind]
                num = ''.join(num)
                num = int(num)
                num = num*2080
                num = str(num)
                lower_list.append(num)
                upper_list.append(num)
            
            
                
    
                
            else:
                print ('Something Went Wrong')
                
        
    return lower_list, upper_list

# %%
s_split = salary_split(df['Salary'])

# %%
lower_series = pd.Series(data=s_split[0])

upper_series = pd.Series(data=s_split[1])

# %%
df = pd.concat([lower_series, df], axis=1)

df =df.rename(columns={0:'lower_salary'})

# %%
df = pd.concat([upper_series, df], axis=1)

df =df.rename(columns={0:'upper_salary'})

# %%
df = df.drop(columns='Salary')

# %%
df.astype({'lower_salary':'float64','upper_salary':'float64'})
# Out:
#      upper_salary  lower_salary          state                    city  \
# 0         84000.0       57000.0             WI                Onalaska
# 1        157000.0      106000.0             KS                 Wichita
# 2        141000.0      105000.0             TN               Nashville
# 3        113000.0       90000.0             OR                Portland
# 4        148000.0       89000.0             PA              Pittsburgh
# ..            ...           ...            ...                     ...
# 495           NaN           NaN             TX               Arlington
# 496      145600.0       91520.0  United States           United States
# 497      107000.0       62000.0             NJ                  Newark
# 498       81120.0       68640.0             NC  Research Triangle Park
# 499      210000.0      140000.0             VA                  McLean
#
#      Position                                          Job Title  Date  \
# 0           1                    Associate Stop Loss Underwriter  30d+
# 1           2                            Manager of Data Science  30d+
# 2           3                        Senior Data Product Manager   11d
# 3           4                           Oncology Nurse Navigator    1d
# 4           5  Head of Artificial Intelligence – Americas Region  30d+
# ..        ...                                                ...   ...
# 495       496                                Cloud Administrator   25d
# 496       497                             Robotics Engineer (AI)    4d
# 497       498  Tchr of English- Newark School of Data Science...  30d+
# 498       499                                       Statistician  30d+
# 499       500  Quantitative Analytics Manager - Data Modeling...    5d
#
#                                                   Logo  \
# 0    https://media.glassdoor.com/sql/453835/the-ins...
# 1    https://media.glassdoor.com/sql/1384674/net-pa...
# 2    https://media.glassdoor.com/sql/1953857/hibob-...
# 3    https://media.glassdoor.com/sql/8794153/inizio...
# 4    https://media.glassdoor.com/sql/27128/covestro...
# ..                                                 ...
# 495  https://media.glassdoor.com/sql/488523/gm-fina...
# 496                                                NaN
# 497  https://media.glassdoor.com/sql/137673/newark-...
# 498  https://media.glassdoor.com/sql/2418223/sciome...
# 499  https://media.glassdoor.com/sql/1585/freddie-m...
#
#                                               Job Link  Company Rating  \
# 0    https://www.glassdoor.com/partner/jobListing.h...             2.7
# 1    https://www.glassdoor.com/partner/jobListing.h...             3.4
# 2    https://www.glassdoor.com/partner/jobListing.h...             4.2
# 3    https://www.glassdoor.com/partner/jobListing.h...             3.6
# 4    https://www.glassdoor.com/partner/jobListing.h...             3.6
# ..                                                 ...             ...
# 495  https://www.glassdoor.com/partner/jobListing.h...             4.0
# 496  https://www.glassdoor.com/partner/jobListing.h...             NaN
# 497  https://www.glassdoor.com/partner/jobListing.h...             3.3
# 498  https://www.glassdoor.com/partner/jobListing.h...             NaN
# 499  https://www.glassdoor.com/partner/jobListing.h...             3.6
#
#                   company_name
# 0         The Insurance Center
# 1               Nuvative, Inc.
# 2                ProviderTrust
# 3                Inizio Engage
# 4                     Covestro
# ..                         ...
# 495               GM Financial
# 496       Alpha Net Consulting
# 497  Newark Board of Education
# 498                 Sciome LLC
# 499                Freddie Mac
#
# [500 rows x 11 columns]

# %%
df.dtypes
# Out:
# upper_salary       object
# lower_salary       object
# state              object
# city               object
# Position            int64
# Job Title          object
# Date               object
# Logo               object
# Job Link           object
# Company Rating    float64
# company_name       object
# dtype: object

# %% [markdown]
# 4.) Drop the unnecessary columns: date posted, logo, job link, position

# %%
df =df.drop(columns=['Position','Date','Logo','Job Link'])

# %%
df.head()
# Out:
#   upper_salary lower_salary state        city  \
# 0        84000        57000    WI    Onalaska
# 1       157000       106000    KS     Wichita
# 2       141000       105000    TN   Nashville
# 3       113000        90000    OR    Portland
# 4       148000        89000    PA  Pittsburgh
#
#                                            Job Title  Company Rating  \
# 0                    Associate Stop Loss Underwriter             2.7
# 1                            Manager of Data Science             3.4
# 2                        Senior Data Product Manager             4.2
# 3                           Oncology Nurse Navigator             3.6
# 4  Head of Artificial Intelligence – Americas Region             3.6
#
#            company_name
# 0  The Insurance Center
# 1        Nuvative, Inc.
# 2         ProviderTrust
# 3         Inizio Engage
# 4              Covestro

# %%
#df.to_csv('wrangled_data_v1.csv')

# %% [markdown]
# Lets use the bls to create some ratios that we can merge into the main datafraeme:
#
# 1.)well use the annual mean wage to compare the listed ranges againsts the state mean
#
# 2.) well use the annual median wage to compare the listed ranges against the state median
#
# 3.) total employment per state in 2023/ job posting total per state in 2024 (small means that the jobs are growing rapidly in that state and big means that new jobs are not coming about as quickly)

# %%
df2 = pd.read_csv('state_ds_bls_stats_may_2023 - Sheet1.csv')

# %%
df2.head()
# Out:
#   Area Name Employment(1)  Annual mean wage(2)  \
# 0        AL          1120                99040
# 1        AK           200                91710
# 2        AZ          3800               112470
# 3        AR           330               117250
# 4        CA         33220               140490
#
#    Annual 10th percentile wage(2)  Annual 25th percentile wage(2)  \
# 0                           54690                           74450
# 1                           51130                           64160
# 2                           65310                           80020
# 3                           82870                          101510
# 4                           68050                           94240
#
#    Annual median wage(2)  Annual 75th percentile wage(2)  \
# 0                 100560                          118130
# 1                  80000                          110480
# 2                 106400                          134410
# 3                 115890                          128490
# 4                 133690                          173250
#
#    Annual 90th percentile wage(2) Employment per 1,000 jobs
# 0                          145250                     0.547
# 1                          142920                     0.638
# 2                          170190                     1.216
# 3                          159700                     0.263
# 4                          213080                     1.851

# %%
df2 = df2.drop(columns=['Annual 10th percentile wage(2)','Annual 25th percentile wage(2)','Annual 75th percentile wage(2)','Annual 90th percentile wage(2)','Employment per 1,000 jobs'])

# %%
df2.columns
# Out:
# Index(['Area Name', 'Employment(1)', 'Annual mean wage(2)',
#        'Annual median wage(2)'],
#       dtype='object')

# %%
for x in range(len(df2['Area Name'])):
    if df2['Area Name'][x] == 'PR':
        print (x)
# Out:
# 39

# %%
df2 =df2.drop(index=[39])
df2.reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 df2 =df2.drop(index=[39])
#       2 df2 = df2.reset_index()
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
#    5352     )
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:7000, in Index.drop(self, labels, errors)
#    6998 if mask.any():
#    6999     if errors != "ignore":
# -> 7000         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7001     indexer = indexer[~mask]
#    7002 return self.delete(indexer)
#
# KeyError: '[39] not found in axis'

# %%
df2.iloc[39]
# Out:
# Area Name                    RI
# Employment(1)               900
# Annual mean wage(2)      127380
# Annual median wage(2)    128350
# Name: 40, dtype: object

# %%
df2['Employment(1)'].unique()
# Out:
# array(['1120', '200', '3800', '330', '33220', '5910', '1190', '530',
#        '3100', '8400', '6510', '150', '710', '6320', '2440', '2270', '-',
#        '2080', '920', '2170', '7400', '4700', '2240', '290', '3850', '90',
#        '1780', '980', '780', '4340', '380', '16390', '6640', '240',
#        '4660', '2130', '2640', '7490', '900', '2090', '20560', '3530',
#        '220', '4810', '5640', '180', '3090'], dtype=object)

# %%
df2.loc[df2['Employment(1)'] == '-', 'Employment(1)'] = 0

# %%
df2['Employment(1)'].unique()
# Out:
# array(['1120', '200', '3800', '330', '33220', '5910', '1190', '530',
#        '3100', '8400', '6510', '150', '710', '6320', '2440', '2270', 0,
#        '2080', '920', '2170', '7400', '4700', '2240', '290', '3850', '90',
#        '1780', '980', '780', '4340', '380', '16390', '6640', '240',
#        '4660', '2130', '2640', '7490', '900', '2090', '20560', '3530',
#        '220', '4810', '5640', '180', '3090'], dtype=object)

# %%
df2 = df2.astype({'Employment(1)':'float64','Annual mean wage(2)':'float64', 'Annual median wage(2)':'float64'})

# %%
df2['Employment(1)']*2
# Out:
# 0      2240.000000
# 1       400.000000
# 2      7600.000000
# 3       660.000000
# 4     66440.000000
# 5     11820.000000
# 6      2380.000000
# 7      1060.000000
# 8      6200.000000
# 9     16800.000000
# 10    13020.000000
# 11      300.000000
# 12     1420.000000
# 13    12640.000000
# 14     4880.000000
# 15     4540.000000
# 16        0.000000
# 17     4160.000000
# 18     1840.000000
# 19     1420.000000
# 20     4340.000000
# 21    14800.000000
# 22     9400.000000
# 23     4480.000000
# 24      580.000000
# 25     7700.000000
# 26      180.000000
# 27     3560.000000
# 28     1960.000000
# 29     1560.000000
# 30     8680.000000
# 31      760.000000
# 32    32780.000000
# 33    13280.000000
# 34      480.000000
# 35     9320.000000
# 36     4260.000000
# 37     5280.000000
# 38    14980.000000
# 40     1800.000000
# 41     4180.000000
# 42      300.000000
# 43     4180.000000
# 44    41120.000000
# 45     7060.000000
# 46      440.000000
# 47     9620.000000
# 48    11280.000000
# 49      360.000000
# 50     6180.000000
# 51     7543.529412
# 52     7691.441753
# Name: Employment(1), dtype: float64

# %%
count = 0
for x in df2['Employment(1)']:
    count += x
    
avg = (count/len(df2))

# %%
df2.loc[df2['Employment(1)'] == 0, 'Employment(1)'] = avg

# %%
df2.loc[51] = ['Remote', np.mean(df2['Employment(1)']), np.mean(df2['Annual mean wage(2)']), np.mean(df2['Annual median wage(2)'])]
df2.loc[52] = ['United States', np.mean(df2['Employment(1)']), np.mean(df2['Annual mean wage(2)']), np.mean(df2['Annual median wage(2)'])]

# %%
df2.dtypes
# Out:
# Area Name                 object
# Employment(1)            float64
# Annual mean wage(2)      float64
# Annual median wage(2)    float64
# dtype: object

# %%
df2.tail(10)
# Out:
#         Area Name  Employment(1)  Annual mean wage(2)  Annual median wage(2)
# 43             TN    2090.000000         97710.000000           92400.000000
# 44             TX   20560.000000        109000.000000          100100.000000
# 45             UT    3530.000000        101780.000000           97490.000000
# 46             VT     220.000000        124430.000000          117500.000000
# 47             VA    4810.000000        139080.000000          136490.000000
# 48             WA    5640.000000        148730.000000          132620.000000
# 49             WV     180.000000         94330.000000           67660.000000
# 50             WI    3090.000000        105250.000000          101850.000000
# 51         Remote    3924.056349        109737.602432          104406.804049
# 52  United States    3924.112153        109737.600176          104406.800294

# %%
df3 = df.merge(df2, left_on='state', right_on='Area Name')

# %%
df3.shape
# Out:
# (499, 11)

# %% [markdown]
# Seems that one of the states was not present on the job postings of 2024

# %%
df3.dtypes
# Out:
# upper_salary              object
# lower_salary              object
# state                     object
# city                      object
# Job Title                 object
# Company Rating           float64
# company_name              object
# Area Name                 object
# Employment(1)            float64
# Annual mean wage(2)      float64
# Annual median wage(2)    float64
# dtype: object

# %%
df3 = df3.astype({'upper_salary':'float64','lower_salary':'float64'})

# %%
df3.dtypes
# Out:
# upper_salary             float64
# lower_salary             float64
# state                     object
# city                      object
# Job Title                 object
# Company Rating           float64
# company_name              object
# Area Name                 object
# Employment(1)            float64
# Annual mean wage(2)      float64
# Annual median wage(2)    float64
# dtype: object

# %%
df3.head()
# Out:
#    upper_salary  lower_salary state        city  \
# 0       84000.0       57000.0    WI    Onalaska
# 1           NaN           NaN    WI  Eau Claire
# 2      160000.0      135000.0    WI     Madison
# 3       84000.0       59000.0    WI      Wausau
# 4       87000.0       58000.0    WI  New Berlin
#
#                                            Job Title  Company Rating  \
# 0                    Associate Stop Loss Underwriter             2.7
# 1                      Marketing Advertising Analyst             3.0
# 2            Manager - IT Infrastructure Engineering             3.9
# 3                    Associate Stop Loss Underwriter             2.7
# 4  Supply Chain Data Analyst (Day Shift) - New Be...             3.5
#
#             company_name Area Name  Employment(1)  Annual mean wage(2)  \
# 0   The Insurance Center        WI         3090.0             105250.0
# 1  Net Health Shops, LLC        WI         3090.0             105250.0
# 2        UW Credit Union        WI         3090.0             105250.0
# 3   The Insurance Center        WI         3090.0             105250.0
# 4            DB SCHENKER        WI         3090.0             105250.0
#
#    Annual median wage(2)
# 0               101850.0
# 1               101850.0
# 2               101850.0
# 3               101850.0
# 4               101850.0

# %%
count_ser = df3['state'].value_counts()

# %%
df3 = df3.merge(count_ser, left_on='state', right_on='state')

# %%
df3.shape
# Out:
# (499, 13)

# %%
df3['total_new_post_rat'] = (df3['Employment(1)'])/(df3['count'])

# %%
df3['total_new_post_rat'].head()
# Out:
# 0    515.0
# 1    515.0
# 2    515.0
# 3    515.0
# 4    515.0
# Name: total_new_post_rat, dtype: float64

# %%
df3 = df3.drop(columns=['Area Name','count'])

# %%
df3['upper_salary'].describe()
# Out:
# count       437.000000
# mean     148165.491991
# std       59175.167609
# min       29120.000000
# 25%      107000.000000
# 50%      143000.000000
# 75%      177000.000000
# max      357000.000000
# Name: upper_salary, dtype: float64

# %%
up_mean = np.mean(df3['upper_salary'])
print (up_med)
df3['upper_salary'] = df3['upper_salary'].fillna(up_mean)
# Out:
# 148165.49199084667

# %%
df3['lower_salary'].describe()
# Out:
# count       437.000000
# mean     104355.331808
# std       39368.058726
# min       29120.000000
# 25%       75000.000000
# 50%       98000.000000
# 75%      127000.000000
# max      250000.000000
# Name: lower_salary, dtype: float64

# %%
df3['lower_salary'] = df3['lower_salary'].fillna(np.mean(df3['lower_salary']))

# %%
df3['range_avg_to_mean_ratio'] = ((df3['upper_salary']+df3['lower_salary'])/2)/df3['Annual mean wage(2)']

# %%
df3['range_avg_to_median_ratio'] = ((df3['upper_salary']+df3['lower_salary'])/2)/df3['Annual median wage(2)']

# %%
df3.head()
# Out:
#     upper_salary   lower_salary state        city  \
# 0   84000.000000   57000.000000    WI    Onalaska
# 1  148165.491991  104355.331808    WI  Eau Claire
# 2  160000.000000  135000.000000    WI     Madison
# 3   84000.000000   59000.000000    WI      Wausau
# 4   87000.000000   58000.000000    WI  New Berlin
#
#                                            Job Title  Company Rating  \
# 0                    Associate Stop Loss Underwriter             2.7
# 1                      Marketing Advertising Analyst             3.0
# 2            Manager - IT Infrastructure Engineering             3.9
# 3                    Associate Stop Loss Underwriter             2.7
# 4  Supply Chain Data Analyst (Day Shift) - New Be...             3.5
#
#             company_name  Employment(1)  Annual mean wage(2)  \
# 0   The Insurance Center         3090.0             105250.0
# 1  Net Health Shops, LLC         3090.0             105250.0
# 2        UW Credit Union         3090.0             105250.0
# 3   The Insurance Center         3090.0             105250.0
# 4            DB SCHENKER         3090.0             105250.0
#
#    Annual median wage(2)  total_new_post_rat  range_avg_to_mean_ratio  \
# 0               101850.0               515.0                 0.669834
# 1               101850.0               515.0                 1.199624
# 2               101850.0               515.0                 1.401425
# 3               101850.0               515.0                 0.679335
# 4               101850.0               515.0                 0.688836
#
#    range_avg_to_median_ratio
# 0                   0.692194
# 1                   1.239670
# 2                   1.448208
# 3                   0.702013
# 4                   0.711831

# %%
df3.to_csv('wrangled_data_v2.csv')
